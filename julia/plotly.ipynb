# %%
using Plots
plot(rand(100,1))
# Out:
# <html>
# <head>
#      <script src="/Users/awd/.julia/v0.5/PlotlyJS/deps/plotly-latest.min.js"></script>
# </head>
# <body>
#      <div id="83261300-3ea5-4bbf-ab91-de71542c2166" class="plotly-graph-div"></div>
#
# <script>
#     window.PLOTLYENV=window.PLOTLYENV || {};
#     window.PLOTLYENV.BASE_URL="https://plot.ly";
# ...
