# %%
using Plots;
plotlyjs()
# Out:
# Plots.PlotlyJSBackend()

# %%
plot(rand(100,1))
# Out:
# <html>
# <head>
#      <script src="/Users/awd/.julia/v0.5/PlotlyJS/deps/plotly-latest.min.js"></script>
# </head>
# <body>
#      <div id="18f32a92-d406-45ea-9c8b-6c1d50a2522d" class="plotly-graph-div"></div>
#
# <script>
#     window.PLOTLYENV=window.PLOTLYENV || {};
#     window.PLOTLYENV.BASE_URL="https://plot.ly";
# ...
